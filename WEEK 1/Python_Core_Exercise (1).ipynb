# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

# --- Task 1 ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate 100 simulated sensor readings

raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    timestamp = start_time + datetime.timedelta(seconds=i * 60)
    timestamp_str = timestamp.strftime('%Y-%m-%d %H:%M:%S')

    device_id = f"DEV{i + 1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    reading = (
        timestamp_str,
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)

print(f"Generated {len(raw_sensor_data)} sensor readings.")


# 1.2 Create temperature_readings

temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': timestamp,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': value
        })

print(f"Temperature readings: {len(temperature_readings)}")


# 1.3 Create unique_locations

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print("Unique locations:", unique_locations)


# 1.4 Create device_stats

device_stats = {}

for device_type in DEVICE_TYPES:
    device_stats[device_type] = (
        float('inf'),
        float('-inf')
    )

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    device_stats[device_type] = (
        min(current_min, value),
        max(current_max, value)
    )

print("Device statistics:")
for device_type, stats in device_stats.items():
    print(f"{device_type}: Min={stats[0]}, Max={stats[1]}")


# --- Task 1.5 ---
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"


# 1.5.1 List Slicing

# 10th to 20th inclusive
# Python indexes start at 0, so index 9 through index 19.
sliced_readings_1 = raw_sensor_data[9:20]

# Every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

print("Sliced readings 1:", sliced_readings_1)
print("Sliced readings 2:", sliced_readings_2)


# 1.5.2 String Slicing

substring_1 = sample_string[6:17]

# "Python" reversed
substring_2 = sample_string[5::-1]

print("substring_1:", substring_1)
print("substring_2:", substring_2)


# 1.5.3 Mixed Slicing

# 5th reading = index 4
fifth_reading_device_type = raw_sensor_data[4][2]

# Last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

print("5th reading device type:", fifth_reading_device_type)
print("Device type suffix:", device_type_suffix)


# --- Task 2 ---
print("\n--- Task 2: Function Definitions and Usage ---")


# 2.1 Get readings by location

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# 2.2 Calculate average temperature

def calculate_average_temperature(temp_data_list):
    if not temp_data_list:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading['temperature_celsius']

    return total / len(temp_data_list)


# 2.3 Generate report line

def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


# Test the functions

lab1_readings = get_readings_by_location(raw_sensor_data, 'Lab1')
print(f"Readings from Lab1: {len(lab1_readings)}")

average_temperature = calculate_average_temperature(temperature_readings)
print(f"Average temperature: {average_temperature:.2f}°C")

if temperature_readings:
    print("Example report line:")
    print(generate_report_line(temperature_readings[0]))


# --- Task 3 ---
print("\n--- Task 3: Core Library Usage ---")


# 3.1 Create directory

reports_dir = 'sensor_reports'

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")


# 3.2 Calculate duration

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    date_format = '%Y-%m-%d %H:%M:%S'

    first_dt = datetime.datetime.strptime(
        first_timestamp_str,
        date_format
    )

    last_dt = datetime.datetime.strptime(
        last_timestamp_str,
        date_format
    )

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24
    minutes = int((seconds % 3600) // 60)

    print(
        f"\nDuration of data collection: "
        f"{days} days, {hours} hours, {minutes} minutes."
    )

else:
    print("\nNot enough data to calculate duration.")


# 3.3 Generate random values

random_values = [random.randint(100, 200) for _ in range(5)]

print("Random values:", random_values)


# --- Task 4 ---
print("\n--- Task 4: File I/O ---")


# 4.1 Write temperature readings to file

report_filename = os.path.join(
    reports_dir,
    'temperature_report.txt'
)

try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')

    print(f"\nTemperature report written to '{report_filename}'.")

except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")


# 4.2 Read report back into a list

read_report_lines = []

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 lines of the report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"\nError reading file '{report_filename}': {e}")


print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Generated 100 sensor readings.
# Temperature readings: 17
# Unique locations: {'Warehouse', 'OfficeB', 'Lab2', 'Lab1', 'OfficeA'}
# Device statistics:
# Temperature_Sensor: Min=18.14, Max=28.13
# Humidity_Sensor: Min=33.4, Max=79.23
# Pressure_Sensor: Min=980.79, Max=1029.73
# Light_Sensor: Min=107.32, Max=961.01
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# Sliced readings 1: [('2026-08-13 08:06:06', 'DEV010', 'Humidity_Sensor', 'OfficeB', 63.46), ('2026-08-13 08:07:06', 'DEV011', 'Temperature_Sensor', 'Lab2', 19.5), ('2026-08-13 08:08:06', 'DEV012', 'Humidity_Sensor', 'OfficeA', 78.8), ('2026-08-13 08:09:06', 'DEV013', 'Pressure_Sensor', 'Lab2', 1020.96), ('2026-08-13 08:10:06', 'DEV014', 'Humidity_Sensor', 'OfficeB', 36.48), ('2026-08-13 08:11:06', 'DEV015', 'Light_Sensor', 'Warehouse', 276.02), ('2026-08-13 08:12:06', 'DEV016', 'Pressure_Sensor', 'OfficeB', 1023.41), ('2026-08-13 08:13:06', 'DEV017', 'Pressure_Sensor', 'Lab1', 993.64), ('2026-08-13 08:14:06', 'DEV018', 'Light_Sensor', 'Warehouse', 828.52), ('2026-08-13 08:15:06', 'DEV019', 'Temperature_Sensor', 'Warehouse', 19.93), ('2026-08-13 08:16:06', 'DEV020', 'Pressure_Sensor', 'Warehouse', 1025.39)]
# Sliced readings 2: [('2026-08-13 07:57:06', 'DEV001', 'Pressure_Sensor', 'Lab1', 981.84), ('2026-08-13 08:02:06', 'DEV006', 'Temperature_Sensor', 'Lab2', 23.59), ('2026-08-13 08:07:06', 'DEV011', 'Temperature_Sensor', 'Lab2', 19.5), ('2026-08-13 08:12:06', 'DEV016', 'Pressure_Sensor', 'OfficeB', 1023.41), ('2026-08-13 08:17:06', 'DEV021', 'Humidity_Sensor', 'Lab1', 52.74), ('2026-08-13 08:22:06', 'DEV026', 'Light_Sensor', 'Lab1', 902.5), ('2026-08-13 08:27:06', 'DEV031', 'Temperature_Sensor', 'Lab1', 22.73), ('2026-08-13 08:32:06', 'DEV036', 'Pressure_Sensor', 'Lab1', 1000.6), ('2026-08-13 08:37:06', 'DEV041', 'Temperature_Sensor', 'OfficeA', 22.64), ('2026-08-13 08:42:06', 'DEV046', 'Pressure_Sensor', 'OfficeA', 981.31), ('2026-08-13 08:47:06', 'DEV051', 'Light_Sensor', 'Lab2', 961.01), ('2026-08-13 08:52:06', 'DEV056', 'Temperature_Sensor', 'OfficeA', 23.01), ('2026-08-13 08:57:06', 'DEV061', 'Pressure_Sensor', 'Warehouse', 984.98), ('2026-08-13 09:02:06', 'DEV066', 'Light_Sensor', 'Lab1', 166.2), ('2026-08-13 09:07:06', 'DEV071', 'Light_Sensor', 'OfficeA', 840.07), ('2026-08-13 09:12:06', 'DEV076', 'Humidity_Sensor', 'OfficeB', 37.28), ('2026-08-13 09:17:06', 'DEV081', 'Temperature_Sensor', 'Warehouse', 23.81), ('2026-08-13 09:22:06', 'DEV086', 'Pressure_Sensor', 'OfficeA', 1002.25), ('2026-08-13 09:27:06', 'DEV091', 'Light_Sensor', 'OfficeB', 906.26), ('2026-08-13 09:32:06', 'DEV096', 'Light_Sensor', 'Lab1', 769.07)]
# substring_1: Programming
# substring_2: nohtyP
# 5th reading device type: Light_Sensor
# Device type suffix: Sensor
#
# --- Task 2: Function Definitions and Usage ---
# Readings from Lab1: 21
# Average temperature: 23.29°C
# Example report line:
# [2026-08-13 08:02:06] Device DEV006 at Lab2: 23.59°C
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.
#
# Duration of data collection: 0 days, 1 hours, 39 minutes.
# Random values: [140, 166, 106, 149, 177]
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# First 3 lines of the report:
# [2026-08-13 08:02:06] Device DEV006 at Lab2: 23.59°C
# [2026-08-13 08:05:06] Device DEV009 at Warehouse: 28.13°C
# [2026-08-13 08:07:06] Device DEV011 at Lab2: 19.5°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
