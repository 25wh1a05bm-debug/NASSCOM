# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05bm-debug/NASSCOM/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A simple Python statement
print("Hello, Python!")  # This is a comment

# Indentation defines blocks
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")  # Not executed
# Out:
# Hello, Python!
# This is indented correctly.

# %%
# Assign values to variables
name = "Alice"
age = 25
height = 5.6

# Print values
print("Name:", name)
print("Age:", age)
print("Height:", height)

# Variables are dynamically typed
name = 123  # Now 'name' holds an integer
print("New value of name:", name)
# Out:
# Name: Alice
# Age: 25
# Height: 5.6
# New value of name: 123
