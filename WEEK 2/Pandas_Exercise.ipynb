# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")

# 1.1 Create a Pandas Series
s1_1 = pd.Series([10, 20, 30, 40, 50])

# 1.2 Create a 3x4 NumPy array with random integers between 1 and 100
np_array1_2 = np.random.randint(1, 101, size=(3, 4))

# 1.3 Convert NumPy array to DataFrame
df1_3 = pd.DataFrame(
    np_array1_2,
    columns=['A', 'B', 'C', 'D']
)


# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")

# Create 100 dates from 2023-01-01 to 2023-04-09
dates = pd.date_range(start='2023-01-01', end='2023-04-09')

# Create the DataFrame
df_sales = pd.DataFrame({
    'Date': dates,
    'Region': np.random.choice(
        ['East', 'West', 'North', 'South'],
        size=num_rows
    ),
    'Product': np.random.choice(
        ['Laptop', 'Mouse', 'Keyboard', 'Monitor'],
        size=num_rows
    ),
    'Sales': np.random.randint(100, 1001, size=num_rows),
    'Quantity': np.random.randint(1, 11, size=num_rows),
})

# Introduce NaN values
sales_nan_indices = np.random.choice(df_sales.index, size=5, replace=False)
quantity_nan_indices = np.random.choice(df_sales.index, size=3, replace=False)

df_sales.loc[sales_nan_indices, 'Sales'] = np.nan
df_sales.loc[quantity_nan_indices, 'Quantity'] = np.nan


# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")

# 3.1 Select Region and Sales columns
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where Product is Laptop
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where Region is East AND Sales > 500
df3_3 = df_sales[
    (df_sales['Region'] == 'East') &
    (df_sales['Sales'] > 500)
]

# 3.4 Get Sales value for the first Monitor entry using .loc and .iloc
monitor_indices = df_sales.index[df_sales['Product'] == 'Monitor']

if len(monitor_indices) > 0:
    first_monitor_index = monitor_indices[0]
    val3_4 = df_sales.loc[first_monitor_index, 'Sales']
else:
    val3_4 = np.nan


# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")

# 4.1 Count missing values in each column
missing_counts4_1 = df_sales.isna().sum()

# 4.2 Fill missing Sales values with the mean Sales
df4_2_filled = df_sales.copy()
df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(
    df4_2_filled['Sales'].mean()
)

# 4.3 Drop rows containing any missing values
df4_3_dropped = df_sales.dropna()


# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")

# 5.1 Create Total_Revenue column
df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

# 5.2 Sort by Date ascending, then Sales descending
df5_2_sorted = df_sales.sort_values(
    by=['Date', 'Sales'],
    ascending=[True, False]
)

# 5.3 Group by Region and calculate sum of Sales and Quantity
df5_3_grouped_region = df_sales.groupby('Region')[
    ['Sales', 'Quantity']
].sum()

# 5.4 Group by Product and calculate average Sales
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()


# Optional: Display results
print("\n--- Task 1 Results ---")
print(s1_1)
print(np_array1_2)
print(df1_3)

print("\n--- Task 2 Results ---")
print(df_sales.head())

print("\n--- Task 3 Results ---")
print(df3_1.head())
print(df3_2.head())
print(df3_3.head())
print("First Monitor Sales:", val3_4)

print("\n--- Task 4 Results ---")
print("Missing values:")
print(missing_counts4_1)
print("\nFilled DataFrame:")
print(df4_2_filled.head())
print("\nDropped DataFrame:")
print(df4_3_dropped.head())

print("\n--- Task 5 Results ---")
print(df5_2_sorted.head())
print("\nGrouped by Region:")
print(df5_3_grouped_region)
print("\nAverage Sales by Product:")
print(df5_4_grouped_product)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
#
# --- Task 2: Synthetic Data Generation for Practice ---
#
# --- Task 3: Indexing and Slicing in DataFrames ---
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
#
# --- Task 1 Results ---
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# [[ 92  35  52  13]
#  [ 80   3 100  24]
#  [ 84  53  78  51]]
#     A   B    C   D
# 0  92  35   52  13
# 1  80   3  100  24
# 2  84  53   78  51
#
# --- Task 2 Results ---
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01  North   Monitor  513.0       4.0         2052.0
# 1 2023-01-02   East   Monitor    NaN      10.0            NaN
# 2 2023-01-03   West     Mouse  916.0       1.0          916.0
# 3 2023-01-04   West    Laptop  115.0       4.0          460.0
# 4 2023-01-05   West  Keyboard    NaN       1.0            NaN
#
# --- Task 3 Results ---
#   Region  Sales
# 0  North  513.0
# 1   East    NaN
# 2   West  916.0
# 3   West  115.0
# 4   West    NaN
#          Date Region Product  Sales  Quantity
# 3  2023-01-04   West  Laptop  115.0       4.0
# 15 2023-01-16   West  Laptop  585.0       5.0
# 18 2023-01-19   East  Laptop  156.0       5.0
# 19 2023-01-20   East  Laptop  346.0       1.0
# 24 2023-01-25   East  Laptop  174.0       6.0
#          Date Region   Product  Sales  Quantity
# 7  2023-01-08   East   Monitor  658.0       1.0
# 8  2023-01-09   East  Keyboard  801.0       5.0
# 23 2023-01-24   East   Monitor  535.0       4.0
# 30 2023-01-31   East    Laptop  611.0       2.0
# 39 2023-02-09   East  Keyboard  904.0       7.0
# First Monitor Sales: 513.0
#
# --- Task 4 Results ---
# Missing values:
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#
# Filled DataFrame:
#         Date Region   Product      Sales  Quantity
# 0 2023-01-01  North   Monitor  513.00000       4.0
# 1 2023-01-02   East   Monitor  505.87234      10.0
# 2 2023-01-03   West     Mouse  916.00000       1.0
# 3 2023-01-04   West    Laptop  115.00000       4.0
# 4 2023-01-05   West  Keyboard  505.87234       1.0
#
# Dropped DataFrame:
#         Date Region   Product  Sales  Quantity
# 0 2023-01-01  North   Monitor  513.0       4.0
# 2 2023-01-03   West     Mouse  916.0       1.0
# 3 2023-01-04   West    Laptop  115.0       4.0
# 5 2023-01-06  North  Keyboard  697.0       2.0
# 6 2023-01-07   West     Mouse  438.0      10.0
#
# --- Task 5 Results ---
#         Date Region   Product  Sales  Quantity  Total_Revenue
# 0 2023-01-01  North   Monitor  513.0       4.0         2052.0
# 1 2023-01-02   East   Monitor    NaN      10.0            NaN
# 2 2023-01-03   West     Mouse  916.0       1.0          916.0
# 3 2023-01-04   West    Laptop  115.0       4.0          460.0
# 4 2023-01-05   West  Keyboard    NaN       1.0            NaN
#
# Grouped by Region:
#           Sales  Quantity
# Region
# East    11726.0     133.0
# North   14208.0     167.0
# South    6726.0      82.0
# West    14892.0     118.0
#
# Average Sales by Product:
# Product
# Keyboard    575.947368
# Laptop      434.590909
# Monitor     485.791667
# Mouse       530.655172
# Name: Sales, dtype: float64
